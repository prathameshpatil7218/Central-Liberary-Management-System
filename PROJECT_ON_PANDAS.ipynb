# %%
import pandas as pd
import numpy as np

# %%
db1 = pd.read_csv('customers01.csv',names=['cust_no', 'firstname', 'lastname', 'gender', 'age', 'profession', 'contact_no', 'email_id', 'city', 'state', 
'isactive', 'created_datetime', 'updated_datetime'])

# %%
db1
# Out:
#      cust_no firstname  lastname gender  age profession  contact_no  \
# 0          1    Leslie      Bass      F   27          B       37307
# 1          2      Judy     Burks      M   53          S       84759
# 2          3    Marsha     Doyle      F   48          B       80932
# 3          4    Alexis    Battle      M   27          S       71701
# 4          5    Martha     Combs      F   49          B       83947
# ..       ...       ...       ...    ...  ...        ...         ...
# 995      964     Jared  McDowell      M   57          S       81891
# 996      965      Rita    Bender      F   46          B       57356
# 997      966     Myron     Blake      M   46          S       82675
# 998      967      Tina   Sargent      F   60          B       32097
# 999      968     Paula     Young      M   32          S       23603
#
#                          email_id        city        state isactive  \
# 0          endslost@everyma1l.org      Gibson     Dellwood        Y
# ...

# %%
db2 = pd.read_csv('products01.csv',names=['product_no', 'product_name', 'description', 'isactive', 'created_datetime', 'updated_datetime'])

# %%
db2
# Out:
#      product_no product_name description isactive  created_datetime  \
# 0             1     Product1  pgqorighfa        Y  03-04-2017 07:58
# 1             2     Product2  lmndaaweth        Y  21-09-2017 12:38
# 2             3     Product3  urifeubrhh        Y  08-09-2017 10:32
# 3             4     Product4  rlpcjxfarp        Y  22-05-2017 05:29
# 4             5     Product5  hzcpozsgfc        Y  02-02-2017 08:40
# ..          ...          ...         ...      ...               ...
# 995         996   Product996  acvxzpvhyu        Y  09-09-2017 07:49
# 996         997   Product997  eguyggimfm        Y  14-09-2017 12:13
# 997         998   Product998  hagbslxugf        Y  20-04-2017 06:25
# 998         999   Product999  iuoraxdrlf        Y  06-03-2017 05:00
# 999        1000  Product1000  ewgaacrkht        N  13-07-2017 02:52
#
#      updated_datetime
# 0    18-10-2017 12:12
# 1    18-10-2017 12:12
# 2    18-10-2017 12:12
# 3    18-10-2017 12:12
# 4    18-10-2017 12:12
# ...

# %%
db3 = pd.read_csv('transactions01.csv',names=['txn_no', 'txn_datetime', 'cust_no', 'amount', 'product_no', 'spend_by'])

# %%
db3.sort_values("cust_no")
# Out:
#      txn_no      txn_datetime  cust_no  amount  product_no spend_by
# 422     423  18-10-2017 12:31        2    4245         136     Cash
# 972     973  18-10-2017 12:31        2    4717         842     Card
# 145     146  18-10-2017 12:31        3    1730         345     Card
# 43       44  18-10-2017 12:31        4    3754         773     Card
# 989     990  18-10-2017 12:31        4    1892         548     Cash
# ..      ...               ...      ...     ...         ...      ...
# 598     599  18-10-2017 12:31      992    4663         825     Card
# 87       88  18-10-2017 12:31      996    2744         615     Card
# 800     801  18-10-2017 12:31      997    2835         742     Cash
# 544     545  18-10-2017 12:31      997    2722           5     Card
# 818     819  18-10-2017 12:31      999    4686         789     Cash
#
# [1000 rows x 6 columns]

# %%
db13=pd.merge(db1,db3,how='left')

# %%
db13
# Out:
#       cust_no firstname lastname gender  age profession  contact_no  \
# 0           1    Leslie     Bass      F   27          B       37307
# 1           2      Judy    Burks      M   53          S       84759
# 2           2      Judy    Burks      M   53          S       84759
# 3           3    Marsha    Doyle      F   48          B       80932
# 4           4    Alexis   Battle      M   27          S       71701
# ...       ...       ...      ...    ...  ...        ...         ...
# 1347      965      Rita   Bender      F   46          B       57356
# 1348      965      Rita   Bender      F   46          B       57356
# 1349      966     Myron    Blake      M   46          S       82675
# 1350      967      Tina  Sargent      F   60          B       32097
# 1351      968     Paula    Young      M   32          S       23603
#
#                           email_id        city       state isactive  \
# 0           endslost@everyma1l.org      Gibson    Dellwood        Y
# ...

# %%
db=pd.merge(db13,db2,how='left',on='product_no')

# %%
db
# Out:
#       cust_no firstname lastname gender  age profession  contact_no  \
# 0           1    Leslie     Bass      F   27          B       37307
# 1           2      Judy    Burks      M   53          S       84759
# 2           2      Judy    Burks      M   53          S       84759
# 3           3    Marsha    Doyle      F   48          B       80932
# 4           4    Alexis   Battle      M   27          S       71701
# ...       ...       ...      ...    ...  ...        ...         ...
# 1347      965      Rita   Bender      F   46          B       57356
# 1348      965      Rita   Bender      F   46          B       57356
# 1349      966     Myron    Blake      M   46          S       82675
# 1350      967      Tina  Sargent      F   60          B       32097
# 1351      968     Paula    Young      M   32          S       23603
#
#                           email_id        city       state  ... txn_no  \
# 0           endslost@everyma1l.org      Gibson    Dellwood  ...    NaN
# ...

# %% [markdown]
# **USECASE 1** - Display First 5 Records

# %%
db.head()
# Out:
#    cust_no firstname lastname gender  age profession  contact_no  \
# 0        1    Leslie     Bass      F   27          B       37307
# 1        2      Judy    Burks      M   53          S       84759
# 2        2      Judy    Burks      M   53          S       84759
# 3        3    Marsha    Doyle      F   48          B       80932
# 4        4    Alexis   Battle      M   27          S       71701
#
#                  email_id     city      state  ... txn_no      txn_datetime  \
# 0  endslost@everyma1l.org   Gibson   Dellwood  ...    NaN               NaN
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue  ...  423.0  18-10-2017 12:31
# 2  rfleming@hotma1l.co.uk  Suwanee     Trabue  ...  973.0  18-10-2017 12:31
# 3    arethe53@ma1lbox.net    Perry  Moxadarla  ...  146.0  18-10-2017 12:31
# 4      ofcame@ma1lbox.org   Morven     Dennis  ...   44.0  18-10-2017 12:31
#
#    amount  product_no spend_by  product_name  description isactive_y  \
# ...

# %% [markdown]
# **USECASE 2** - Customers Who Purchased More than 3 Products

# %%
a=db['cust_no'].value_counts().nlargest(3,keep='all')
a
# Out:
# 391    5
# 241    5
# 86     4
# 326    4
# 989    4
# 709    4
# 356    4
# 187    4
# 321    4
# 558    4
# 753    4
# 828    4
# 167    4
# 237    4
# 537    4
# 331    4
# 578    4
# 4      4
# 735    4
# Name: cust_no, dtype: int64

# %%
len(a)
# Out:
# 19

# %%
a = db.groupby(['cust_no'])['firstname'].count()

# %%
a= a.reset_index()

# %%
len(a[a["firstname"]>3])
# Out:
# 19

# %% [markdown]
# **USECASE 3** - Top 5 Most Demanded Products

# %%
db['product_no'].value_counts().head()
# Out:
# 900.0    5
# 768.0    5
# 427.0    5
# 82.0     5
# 637.0    4
# Name: product_no, dtype: int64

# %%
db['product_name'].value_counts().head()
# Out:
# Product900    5
# Product768    5
# Product82     5
# Product427    5
# Product746    4
# Name: product_name, dtype: int64

# %% [markdown]
# **USECASE 4** - Top 5 Transactions Amount

# %%
db.sort_values('amount',ascending=False).head()
# Out:
#      cust_no firstname lastname gender  age profession  contact_no  \
# 354      363       Ian    Poole      F   43          B       45640
# 134      151  Rochelle    Olson      F   59          B       34865
# 323      338    Daniel   Cooley      M   32          S       88866
# 627      622       Ted   Conner      M   28          S       21706
# 412      419    Marion     Good      F   42          B       65595
#
#                     email_id         city           state  ... txn_no  \
# 354       acannon@ma1l2u.org      Hoboken           Purdy  ...    431
# 134     bkelly@everyma1l.com     Hortense           Cecil  ...    422
# 323        csanders@gma1l.us   Bainbridge         Pioneer  ...    537
# 627  dconley20@everyma1l.org      Acworth  Chandlersville  ...    788
# 412       jcrane@ma1lbox.biz  Hogansville        Graylock  ...    744
#
#             txn_datetime amount  product_no spend_by  product_name  \
# 354  2017-10-18 12:31:46    469         118     Card    Product118
# ...

# %% [markdown]
# **USECASE 5** - Distinct Professions

# %%
db['profession'].unique()
# Out:
# array(['S', 'B'], dtype=object)

# %% [markdown]
# **USECASE 6** - Highest Age in Customer's Datasets

# %%
db['age'].max()
# Out:
# 64

# %%
db.nlargest(1,'age',keep='all')
# Out:
#      cust_no  firstname   lastname gender  age profession  contact_no  \
# 63        59    Randall    Lambert      F   64          B       41458
# 64        59    Randall    Lambert      F   64          B       41458
# 146      164    Brianna     Vinson      M   64          S       48042
# 147      164    Brianna     Vinson      M   64          S       48042
# 157      170      Marie    Hoffman      M   64          S       57181
# 184      202      Lewis       Wynn      M   64          S       64991
# 185      202      Lewis       Wynn      M   64          S       64991
# 186      202      Lewis       Wynn      M   64          S       64991
# 212      230       Jean  Singleton      M   64          S       30274
# 267      278  Christine     Vinson      M   64          S       89928
# 268      278  Christine     Vinson      M   64          S       89928
# 269      278  Christine     Vinson      M   64          S       89928
# ...

# %% [markdown]
# **USECASE 7** - cust_no, gender, age, profession, contact_no, product_no, product_name, txn_datetime, spend_by, amount of custno=923

# %%
db
# Out:
#      cust_no firstname  lastname gender  age profession  contact_no  \
# 0          2      Judy     Burks      M   53          S       84759
# 1          2      Judy     Burks      M   53          S       84759
# 2          3    Marsha     Doyle      F   48          B       80932
# 3          4    Alexis    Battle      M   27          S       71701
# 4          4    Alexis    Battle      M   27          S       71701
# ..       ...       ...       ...    ...  ...        ...         ...
# 995      964     Jared  McDowell      M   57          S       81891
# 996      965      Rita    Bender      F   46          B       57356
# 997      965      Rita    Bender      F   46          B       57356
# 998      966     Myron     Blake      M   46          S       82675
# 999      967      Tina   Sargent      F   60          B       32097
#
#                          email_id        city        state  ... txn_no  \
# 0          rfleming@hotma1l.co.uk     Suwanee       Trabue  ...    423
# ...

# %%
aa=db[['cust_no','gender','age','profession','contact_no','product_no','product_name','txn_datetime','spend_by','amount']]
aa.set_index('cust_no',inplace=True)
aa.loc[923]
# Out:
#         gender  age profession  contact_no  product_no product_name  \
# cust_no
# 923          F   46          B       25436         376   Product376
# 923          F   46          B       25436         113   Product113
# 923          F   46          B       25436         644   Product644
#
#                 txn_datetime spend_by  amount
# cust_no
# 923      2017-10-18 12:31:45     Card    2559
# 923      2017-10-18 12:31:46     Card    2303
# 923      2017-10-18 12:31:46     Cash    4553

# %%
db.loc[db['cust_no']==923]
# Out:
#       cust_no firstname lastname gender  age profession  contact_no  \
# 1253      923   Russell  Walters      F   46          B       25436
# 1254      923   Russell  Walters      F   46          B       25436
# 1255      923   Russell  Walters      F   46          B       25436
#
#                  email_id      city  state  ... txn_no      txn_datetime  \
# 1253  esears55@ma1lbox.us  Cuthbert  Odell  ...    1.0  18-10-2017 12:31
# 1254  esears55@ma1lbox.us  Cuthbert  Odell  ...  335.0  18-10-2017 12:31
# 1255  esears55@ma1lbox.us  Cuthbert  Odell  ...  933.0  18-10-2017 12:31
#
#       amount  product_no spend_by  product_name  description isactive_y  \
# 1253  2559.0       376.0     Card    Product376   yrvkpocxka          Y
# 1254  2303.0       113.0     Card    Product113   fktwodxvig          Y
# 1255  4553.0       644.0     Cash    Product644   pfmsjwfntn          Y
#
#      created_datetime_y updated_datetime_y
# 1253   06-09-2017 05:06   18-10-2017 12:12
# ...

# %%
db.loc[db['cust_no']==923,['cust_no','gender','age','profession','contact_no','product_no','product_name','txn_datetime','spend_by','amount']]
# Out:
#       cust_no gender  age profession  contact_no  product_no product_name  \
# 1253      923      F   46          B       25436       376.0   Product376
# 1254      923      F   46          B       25436       113.0   Product113
# 1255      923      F   46          B       25436       644.0   Product644
#
#           txn_datetime spend_by  amount
# 1253  18-10-2017 12:31     Card  2559.0
# 1254  18-10-2017 12:31     Card  2303.0
# 1255  18-10-2017 12:31     Cash  4553.0

# %% [markdown]
# **USECASE 8** - Load All Three PSV Files and Display First 5 Records

# %%
dbt1=pd.read_csv('customers.txt',sep='|',names=['cust_no', 'firstname', 'lastname', 'gender', 'age', 'profession', 'contact_no', 'email_id', 'city', 'state', 
'isactive', 'created_datetime', 'updated_datetime'])

dbt2 = pd.read_csv('products.txt',sep='|',names=['product_no', 'product_name', 'description', 'isactive', 'created_datetime', 'updated_datetime'])

dbt3 = pd.read_csv('transactions.txt',sep='|',names=['txn_no', 'txn_datetime', 'cust_no', 'amount', 'product_no', 'spend_by'])

# %%
dbt1
# Out:
#      cust_no firstname   lastname gender  age profession  contact_no  \
# 0          1    Leslie       Bass      F   27          B       37307
# 1          2      Judy      Burks      M   53          S       84759
# 2          3    Marsha      Doyle      F   48          B       80932
# 3          4    Alexis     Battle      M   27          S       71701
# 4          5    Martha      Combs      F   49          B       83947
# ..       ...       ...        ...    ...  ...        ...         ...
# 995      996   Roxanne  Velazquez      M   37          S       57463
# 996      997   Kristen       Wall      F   20          B       62662
# 997      998     Terry  Blackwell      M   28          S       49457
# 998      999     Betty       Leon      F   23          B       69268
# 999     1000    Connie    Andrews      M   47          S       78445
#
#                         email_id                 city      state isactive  \
# ...

# %%
dbt2
# Out:
#      product_no product_name description isactive     created_datetime  \
# 0             1     Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1             2     Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2             3     Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3             4     Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4             5     Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
# ..          ...          ...         ...      ...                  ...
# 995         996   Product996  acvxzpvhyu        Y  2017-09-09 07:49:14
# 996         997   Product997  eguyggimfm        Y  2017-09-14 12:13:29
# 997         998   Product998  hagbslxugf        Y  2017-04-20 06:25:03
# 998         999   Product999  iuoraxdrlf        Y  2017-03-06 05:00:08
# 999        1000  Product1000  ewgaacrkht        N  2017-07-13 02:52:44
#
#         updated_datetime
# 0    2017-10-18 12:12:38
# 1    2017-10-18 12:12:38
# 2    2017-10-18 12:12:38
# ...

# %%
dbt3
# Out:
#      txn_no         txn_datetime  cust_no  amount  product_no spend_by
# 0         1  2017-10-18 12:31:45      923    2559         376     Card
# 1         2  2017-10-18 12:31:45      219    1706         151     Card
# 2         3  2017-10-18 12:31:45      927    3462         707     Cash
# 3         4  2017-10-18 12:31:45      806     865         539     Card
# 4         5  2017-10-18 12:31:45      958    2494          25     Card
# ..      ...                  ...      ...     ...         ...      ...
# 995     996  2017-10-18 12:31:46      653    2872         155     Cash
# 996     997  2017-10-18 12:31:46      849     815         386     Card
# 997     998  2017-10-18 12:31:46      939    3932         529     Card
# 998     999  2017-10-18 12:31:46      547    3021         774     Cash
# 999    1000  2017-10-18 12:31:46      204    2314         828     Card
#
# [1000 rows x 6 columns]

# %%
dbt13 = pd.merge(dbt1,dbt3)
dbt13
# Out:
#      cust_no firstname   lastname gender  age profession  contact_no  \
# 0          2      Judy      Burks      M   53          S       84759
# 1          2      Judy      Burks      M   53          S       84759
# 2          3    Marsha      Doyle      F   48          B       80932
# 3          4    Alexis     Battle      M   27          S       71701
# 4          4    Alexis     Battle      M   27          S       71701
# ..       ...       ...        ...    ...  ...        ...         ...
# 995      992    Tamara       Shaw      M   32          S       78378
# 996      996   Roxanne  Velazquez      M   37          S       57463
# 997      997   Kristen       Wall      F   20          B       62662
# 998      997   Kristen       Wall      F   20          B       62662
# 999      999     Betty       Leon      F   23          B       69268
#
#                     email_id                 city      state isactive  \
# ...

# %%
dbt = pd.merge(dbt13,dbt2,how='left',on='product_no')
dbt
# Out:
#      cust_no firstname   lastname gender  age profession  contact_no  \
# 0          2      Judy      Burks      M   53          S       84759
# 1          2      Judy      Burks      M   53          S       84759
# 2          3    Marsha      Doyle      F   48          B       80932
# 3          4    Alexis     Battle      M   27          S       71701
# 4          4    Alexis     Battle      M   27          S       71701
# ..       ...       ...        ...    ...  ...        ...         ...
# 995      992    Tamara       Shaw      M   32          S       78378
# 996      996   Roxanne  Velazquez      M   37          S       57463
# 997      997   Kristen       Wall      F   20          B       62662
# 998      997   Kristen       Wall      F   20          B       62662
# 999      999     Betty       Leon      F   23          B       69268
#
#                     email_id                 city      state  ... txn_no  \
# ...

# %%
dbt.head()
# Out:
#    cust_no firstname lastname gender  age profession  contact_no  \
# 0        2      Judy    Burks      M   53          S       84759
# 1        2      Judy    Burks      M   53          S       84759
# 2        3    Marsha    Doyle      F   48          B       80932
# 3        4    Alexis   Battle      M   27          S       71701
# 4        4    Alexis   Battle      M   27          S       71701
#
#                  email_id     city      state  ... txn_no  \
# 0  rfleming@hotma1l.co.uk  Suwanee     Trabue  ...    423
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue  ...    973
# 2    arethe53@ma1lbox.net    Perry  Moxadarla  ...    146
# 3      ofcame@ma1lbox.org   Morven     Dennis  ...     44
# 4      ofcame@ma1lbox.org   Morven     Dennis  ...    350
#
#           txn_datetime amount  product_no spend_by  product_name  description  \
# 0  2017-10-18 12:31:46   4245         136     Cash    Product136   ecfldqedud
# ...

# %% [markdown]
# **USECASE 9** - Load All Three JSON Files and Display First 5 Records

# %%
dbj1 = pd.read_json('customers.json',lines=True)
dbj2 = pd.read_json('products.json',lines=True)
dbj3 = pd.read_json('transactions.json',lines=True)

# %%
dbj1
# Out:
#     custno  firstname    lastname  gender  age          profession  \
# 0        1        Dai       Noble       2   53     Human Resources
# 1        2        Kay        Wise       2   26    Public Relations
# 2        3       Amir        Pace       1   43  Customer Relations
# 3        4  Sebastian       Lopez       2   32  Customer Relations
# 4        5      Brian      Maddox       1   40   Quality Assurance
# ..     ...        ...         ...     ...  ...                 ...
# 95      96     Tanner     Webster       1   29          Accounting
# 96      97    Tatiana       Gates       2   54         Advertising
# 97      98     Baxter  Valenzuela       1   43    Asset Management
# 98      99   Chadwick     Mcclure       2   42             Payroll
# 99     100       Tate       Booth       2   53         Advertising
#
#         contactNo                               emailId                 city  \
# 0   1644101928099          eu.lacus.Quisque@loremac.com               Berlin
# ...

# %%
dbj2
# Out:
#     productno     productName Description  isActive createdDate UpdatedDate
# 0         100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1         101          Toyota         six         2  2017-10-03  2017-11-13
# 2         102  General Motors         two         1  2017-09-18  2017-11-03
# 3         103         Renault       eight         2  2017-10-05  2017-11-13
# 4         104        Kenworth       three         1  2017-05-03  2017-11-04
# ..        ...             ...         ...       ...         ...         ...
# 95        195             BMW        nine         2  2017-05-06  2017-11-18
# 96        196            Fiat       seven         2  2016-11-13  2017-11-17
# 97        197         Renault        five         1  2017-09-23  2017-11-16
# 98        198      Kia Motors       seven         2  2017-05-27  2017-11-02
# 99        199      RAM Trucks       eight         2  2017-04-05  2017-11-20
#
# [100 rows x 6 columns]

# %%
dbj3
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 0       1  2018-07-31      71     181         19        2
# 1       2  2017-04-02      44     401         48        2
# 2       3  2018-01-31      45    1808         44        2
# 3       4  2018-04-02      62      65         22        2
# 4       5  2017-08-17      88    1149         74        2
# ..    ...         ...     ...     ...        ...      ...
# 95     96  2017-02-14      81     124         29        1
# 96     97  2017-11-16       2     672         78        1
# 97     98  2018-08-14      43     538         61        1
# 98     99  2017-05-06      74    1856         95        2
# 99    100  2017-08-28      85     273         99        2
#
# [100 rows x 6 columns]

# %%
dbj13 = pd.merge(dbj1,dbj3,how='left',on='custno')
dbj13
# Out:
#      custno  firstname    lastname  gender  age          profession  \
# 0         1        Dai       Noble       2   53     Human Resources
# 1         2        Kay        Wise       2   26    Public Relations
# 2         2        Kay        Wise       2   26    Public Relations
# 3         3       Amir        Pace       1   43  Customer Relations
# 4         4  Sebastian       Lopez       2   32  Customer Relations
# ..      ...        ...         ...     ...  ...                 ...
# 131      96     Tanner     Webster       1   29          Accounting
# 132      97    Tatiana       Gates       2   54         Advertising
# 133      98     Baxter  Valenzuela       1   43    Asset Management
# 134      99   Chadwick     Mcclure       2   42             Payroll
# 135     100       Tate       Booth       2   53         Advertising
#
#          contactNo                               emailId                 city  \
# ...

# %%
dbj = pd.merge(dbj13,dbj2,how='left',on='productno')
dbj
# Out:
#      custno  firstname    lastname  gender  age          profession  \
# 0         1        Dai       Noble       2   53     Human Resources
# 1         2        Kay        Wise       2   26    Public Relations
# 2         2        Kay        Wise       2   26    Public Relations
# 3         3       Amir        Pace       1   43  Customer Relations
# 4         4  Sebastian       Lopez       2   32  Customer Relations
# ..      ...        ...         ...     ...  ...                 ...
# 131      96     Tanner     Webster       1   29          Accounting
# 132      97    Tatiana       Gates       2   54         Advertising
# 133      98     Baxter  Valenzuela       1   43    Asset Management
# 134      99   Chadwick     Mcclure       2   42             Payroll
# 135     100       Tate       Booth       2   53         Advertising
#
#          contactNo                               emailId                 city  \
# ...

# %%
dbj.head()
# Out:
#    custno firstname lastname  gender  age         profession      contactNo  \
# 0       2       Kay     Wise       2   26   Public Relations  1674031917099
# 1       2       Kay     Wise       2   26   Public Relations  1674031917099
# 2       5     Brian   Maddox       1   40  Quality Assurance  1646080399299
# 3       5     Brian   Maddox       1   40  Quality Assurance  1646080399299
# 4       7   Abraham    Silva       2   39         Accounting  1694050548699
#
#                        emailId                  city       state  ...  txnno  \
# 0         ridiculus@Sednunc.ca             Oldenzaal  Overijssel  ...      8
# 1         ridiculus@Sednunc.ca             Oldenzaal  Overijssel  ...     97
# 2        ac.facilisis@Duis.com       Greater Sudbury     Ontario  ...     24
# 3        ac.facilisis@Duis.com       Greater Sudbury     Ontario  ...     39
# 4  dui.Cras.pellentesque@ut.ca  San José de Alajuela    Alajuela  ...     34
#
# ...

# %% [markdown]
# **USECASE 10** - Load All Three XML Files and Display First 5 Records

# %%
dbx1 = pd.read_xml('customers.xml')
dbx2 = pd.read_xml('products.xml')
dbx3 = pd.read_xml('transactions.xml')

# %%
dbx1
# Out:
#     custno firstname  lastname  gender  age          profession  \
# 0        1    Teegan   Hubbard       2   33     Human Resources
# 1        2    Deacon    Briggs       2   54  Customer Relations
# 2        3   Mallory   Shelton       1   57  Customer Relations
# 3        4     Quinn  Clements       2   43     Media Relations
# 4        5    Arthur     Hurst       2   41        Tech Support
# ..     ...       ...       ...     ...  ...                 ...
# 95      96   Harriet    Moreno       1   33    Legal Department
# 96      97      Nell    Sparks       1   63    Asset Management
# 97      98    Ashely      Lynn       1   30    Customer Service
# 98      99     Emily  Williams       2   30            Finances
# 99     100    Tashya    Dudley       1   31  Customer Relations
#
#         contactNo                                       emailId  \
# 0   1681121691699                     nibh.Quisque@placerat.com
# 1   1631082682999                    facilisis.eget@Nullaeu.com
# ...

# %%
dbx2
# Out:
#     productno     productName Description  isActive createdDate UpdatedDate
# 0         100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1         101           Honda       eight         1  2017-04-10  2017-11-11
# 2         102             GMC       three         2  2017-02-09  2017-11-17
# 3         103           Lexus       eight         2  2017-06-01  2017-11-04
# 4         104           Smart        five         2  2017-08-10  2017-11-16
# ..        ...             ...         ...       ...         ...         ...
# 95        195           Honda        four         2  2016-11-09  2017-11-19
# 96        196     Tata Motors       three         2  2016-11-17  2017-11-03
# 97        197        Kenworth        nine         1  2017-09-21  2017-11-09
# 98        198           Skoda        nine         2  2017-04-14  2017-11-14
# 99        199             BMW         six         2  2017-06-23  2017-11-15
#
# [100 rows x 6 columns]

# %%
dbx3
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 0       1  2018-09-16       6     576         73        1
# 1       2  2018-02-11      96    1038         40        2
# 2       3  2017-06-13      17     673          2        1
# 3       4  2017-07-25      89    1284        100        2
# 4       5  2017-06-15       9    1685         56        2
# ..    ...         ...     ...     ...        ...      ...
# 95     96  2018-11-10      59    1388         26        2
# 96     97  2017-09-13      57    1261         36        2
# 97     98  2017-10-29       7      93         60        1
# 98     99  2017-09-30       4     643         38        1
# 99    100  2017-10-12      77    1902         54        2
#
# [100 rows x 6 columns]

# %%
dbx13 = pd.merge(dbx1,dbx3)
dbx13
# Out:
#     custno firstname  lastname  gender  age          profession  \
# 0        1    Teegan   Hubbard       2   33     Human Resources
# 1        2    Deacon    Briggs       2   54  Customer Relations
# 2        3   Mallory   Shelton       1   57  Customer Relations
# 3        4     Quinn  Clements       2   43     Media Relations
# 4        4     Quinn  Clements       2   43     Media Relations
# ..     ...       ...       ...     ...  ...                 ...
# 95      96   Harriet    Moreno       1   33    Legal Department
# 96      97      Nell    Sparks       1   63    Asset Management
# 97      98    Ashely      Lynn       1   30    Customer Service
# 98     100    Tashya    Dudley       1   31  Customer Relations
# 99     100    Tashya    Dudley       1   31  Customer Relations
#
#         contactNo                                       emailId  \
# 0   1681121691699                     nibh.Quisque@placerat.com
# 1   1631082682999                    facilisis.eget@Nullaeu.com
# ...

# %%
dbx = pd.merge(dbx13,dbx2,how='left',on='productno')

# %%
dbx
# Out:
#     custno firstname  lastname  gender  age          profession  \
# 0        1    Teegan   Hubbard       2   33     Human Resources
# 1        2    Deacon    Briggs       2   54  Customer Relations
# 2        3   Mallory   Shelton       1   57  Customer Relations
# 3        4     Quinn  Clements       2   43     Media Relations
# 4        4     Quinn  Clements       2   43     Media Relations
# ..     ...       ...       ...     ...  ...                 ...
# 95      96   Harriet    Moreno       1   33    Legal Department
# 96      97      Nell    Sparks       1   63    Asset Management
# 97      98    Ashely      Lynn       1   30    Customer Service
# 98     100    Tashya    Dudley       1   31  Customer Relations
# 99     100    Tashya    Dudley       1   31  Customer Relations
#
#         contactNo                                       emailId  \
# 0   1681121691699                     nibh.Quisque@placerat.com
# 1   1631082682999                    facilisis.eget@Nullaeu.com
# ...

# %%
dbx.head()
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       4     Quinn  Clements       2   43     Media Relations  1618122268999
#
#                           emailId             city         state  ...  txnno  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire  ...     29
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU  ...     44
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI  ...     85
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H  ...     41
# 4  metus.Vivamus.euismod@urna.edu          Heredia             H  ...     99
#
# ...
